# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Homework: Plotting With Pandas
#
# _Authors: Kevin Coyle (L.A.)_
#
# ---

# %% [markdown]
# Welcome!

# %% [markdown]
# #### Pandas: Plotting Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll practice the following programming concepts we've covered in class:
# * Plotting with Pandas.
# * Determining best plot given a data set.

# %% [markdown]
# #### #1. Import Pandas, `Matplotlib.pyplot`, and NumPy. Don't forget the line that makes `matplotlib` render in a Jupyter Notebook!

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
# read the dataset as a DataFrame into a variable named 'prod'
nba_df = pd.read_csv('../hw-10wk-13d/NBA_players_2015.csv')

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
nba_df.head(5)
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %%
nba_df['age'].plot(kind='hist')

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to `20`.

# %%
nba_df['age'].plot(kind='hist')
nba_df['age'].plot(kind='hist',bins=20)

# %% [markdown]
# #### #6. Discuss the difference in the two plots and the implications.

# %% [markdown]
# While skewed, the plot with fewer bins leads one to believe that the bin to the right of the highest-numbered age bin is the second largest. The second-largest bin occurs right after 22 and before 25.

# %% [markdown]
# #### #7. Rename the `position` column `'pos'` with the following `C:5`, `G:1`, and `F:3`. Then create a scatter matrix plot with the `'pos'`, `'pts'`, `'age'`, and `'fg'` columns.

# %%
nba_df.rename(columns={'position':'pos'},inplace=True)

# %%
# using the apply method
# def make_pos_numeric(position):
#     if position == 'C':
#         return 5
#     if position == 'F':
#         return 3
#     if position == 'G':
#         return 1
# # make_pos_numeric('C')
# nba_df=nba_df['pos'].apply(make_pos_numeric)
# nba_df.head()

# # using the replace method
nba_df.replace({'pos':{'G':1,'F':3,'C':5}})
# Out:
#      season_end                 player  pos  age bref_team_id   g  gs    mp  \
# 0          2015             Quincy Acy    3   24          NYK  52  21  19.2
# 1          2015           Jordan Adams    1   20          MEM  18   0   7.3
# 2          2015           Steven Adams    5   21          OKC  51  50  24.2
# 3          2015            Jeff Adrien    3   28          MIN  17   0  12.6
# 4          2015          Arron Afflalo    1   29          TOT  60  54  32.5
# 5          2015          Alexis Ajinca    5   26          NOP  51   6  14.0
# 6          2015         Furkan Aldemir    3   23          PHI  25   1  10.7
# 7          2015           Cole Aldrich    5   26          NYK  45  12  15.9
# 8          2015      LaMarcus Aldridge    3   29          POR  54  54  36.2
# 9          2015            Lavoy Allen    3   25          IND  47   0  19.6
# 10         2015             Tony Allen    1   33          MEM  54  36  25.6
# 11         2015        Al-Farouq Aminu    3   24          DAL  60   3  17.0
# 12         2015         Louis Amundson    3   32          TOT  34  20  16.8
# 13         2015         Chris Andersen    5   36          MIA  46  18  19.5
# 14         2015          Alan Anderson    1   32          BRK  62  19  23.8
# 15         2015          Kyle Anderson    3   21          SAS  27   8  12.6
# 16         2015          Ryan Anderson    3   26          NOP  52   5  28.6
# 17         2015  Giannis Antetokounmpo    1   20          MIL  63  53  30.4
# 18         2015        Carmelo Anthony    3   30          NYK  40  40  35.7
# 19         2015           Joel Anthony    5   32          DET  32   0   5.8
# 20         2015             Pero Antic    3   32          ATL  47   2  16.0
# 21         2015           Trevor Ariza    3   29          HOU  63  63  35.6
# 22         2015         Darrell Arthur    3   26          DEN  53   3  17.2
# 23         2015              Omer Asik    5   28          NOP  61  61  26.1
# 24         2015          D.J. Augustin    1   27          TOT  63  14  24.3
# 25         2015             Jeff Ayres    3   27          SAS  37   0   7.6
# 26         2015           Luke Babbitt    3   25          NOP  54  19  13.8
# 27         2015       Cameron Bairstow    3   24          CHI  14   1   4.1
# 28         2015        Leandro Barbosa    1   32          GSW  49   1  13.4
# 29         2015             Jose Barea    1   30          DAL  65  10  17.6
# ..          ...                    ...  ...  ...          ...  ..  ..   ...
# 448        2015              John Wall    1   24          WAS  64  64  35.6
# 449        2015         Gerald Wallace    3   32          BOS  27   0   8.2
# 450        2015            T.J. Warren    3   21          PHO  24   0  11.0
# 451        2015            C.J. Watson    1   30          IND  44  21  25.8
# 452        2015            Travis Wear    3   24          NYK  45   1  12.4
# 453        2015        Martell Webster    3   28          WAS  21   0  10.1
# 454        2015             David West    3   34          IND  48  48  29.2
# 455        2015      Russell Westbrook    1   26          OKC  48  48  33.4
# 456        2015       Hassan Whiteside    5   25          MIA  35  20  22.0
# 457        2015     Shayne Whittington    3   23          IND  20   0   5.4
# 458        2015         Andrew Wiggins    1   19          MIN  62  62  35.0
# 459        2015            C.J. Wilcox    1   24          LAC  16   0   5.0
# 460        2015         Deron Williams    1   30          BRK  48  35  31.4
# 461        2015       Derrick Williams    3   23          SAC  54   5  17.7
# 462        2015        Elliot Williams    1   25          TOT   8   0   9.4
# 463        2015         Louis Williams    1   28          TOR  63   0  24.7
# 464        2015        Marvin Williams    3   28          CHO  58  18  24.5
# 465        2015            Mo Williams    1   32          TOT  51  29  29.4
# 466        2015        Reggie Williams    3   28          SAS   7   0   4.9
# 467        2015        Shawne Williams    3   28          TOT  50  22  19.5
# 468        2015            Jeff Withey    5   24          NOP  31   0   6.3
# 469        2015           Nate Wolters    1   23          TOT  21   0  11.8
# 470        2015         Brandan Wright    3   27          TOT  60   0  17.2
# 471        2015          Dorell Wright    3   29          POR  35   1  10.9
# 472        2015            Tony Wroten    1   21          PHI  30  15  29.8
# 473        2015            James Young    1   19          BOS  27   0  10.9
# 474        2015             Nick Young    1   29          LAL  42   0  23.8
# 475        2015         Thaddeus Young    3   26          TOT  58  50  31.8
# 476        2015            Cody Zeller    5   22          CHO  61  44  24.1
# 477        2015           Tyler Zeller    5   25          BOS  62  39  20.8
#
#       fg   fga  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0    2.2   4.6  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7  -3.4  -0.3
# 1    1.0   2.1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8  -0.5   0.0
# 2    3.0   5.5  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0  -0.1   0.6
# 3    1.1   2.6  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8  -1.8   0.0
# 4    5.0  11.8  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4  -1.6   0.2
# 5    2.8   4.8  ...   15.3  20.8  1.8  0.9  2.7  0.181   0.4   0.2   0.7   0.5
# 6    0.6   1.3  ...   21.1   7.8  0.3  0.4  0.7  0.127  -2.9   3.1   0.2   0.2
# 7    2.3   4.8  ...   15.5  17.9  0.4  0.9  1.3  0.089  -2.6   2.3  -0.3   0.3
# 8    9.1  20.2  ...    7.3  29.9  3.3  3.2  6.5  0.161  -0.4   0.3  -0.1   0.9
# 9    2.7   5.5  ...   10.0  15.2  1.5  1.4  2.9  0.152  -0.5   2.4   1.9   0.9
# 10   3.5   7.0  ...   14.1  16.4  0.8  2.6  3.4  0.118  -0.3   3.6   3.2   1.8
# 11   2.0   4.7  ...   11.8  15.7  0.9  1.7  2.6  0.124  -0.6   3.0   2.3   1.1
# 12   2.1   4.4  ...   14.4  15.7  0.3  0.4  0.8  0.066  -2.1   1.6  -0.5   0.2
# 13   1.9   3.3  ...   11.3  11.7  1.8  1.1  3.0  0.159  -1.0   2.2   1.3   0.7
# 14   2.5   5.7  ...   11.8  13.7  1.3  0.9  2.1  0.070  -0.2  -0.3  -0.5   0.6
# 15   1.1   3.0  ...   10.3  13.0 -0.2  0.6  0.3  0.048  -4.9   2.4  -2.5   0.0
# 16   5.1  12.5  ...    7.3  23.5  2.9  0.7  3.5  0.114   2.8  -3.2  -0.4   0.6
# 17   4.6   9.3  ...   16.4  19.7  1.6  3.2  4.8  0.121  -1.6   2.6   1.0   1.5
# 18   9.0  20.2  ...    8.9  32.3  2.5  0.6  3.0  0.101   3.7  -2.2   1.5   1.3
# 19   0.5   0.8  ...   15.9   8.9  0.2  0.3  0.5  0.123  -4.5   3.9  -0.6   0.1
# 20   1.7   4.7  ...   13.4  18.2  0.1  0.7  0.8  0.050  -1.8  -1.4  -3.1  -0.2
# 21   4.4  11.3  ...   12.0  16.7  1.6  3.1  4.7  0.100   0.2   1.3   1.5   2.0
# 22   2.8   6.8  ...   10.5  20.4  0.1  0.9  1.0  0.053  -1.5   0.8  -0.6   0.3
# 23   2.7   5.3  ...   16.2  13.7  2.2  1.7  3.9  0.118  -1.3   0.5  -0.9   0.5
# 24   3.5   8.5  ...   16.2  21.2  2.4  0.8  3.3  0.103   0.9  -2.7  -1.8   0.1
# 25   1.0   1.7  ...   16.7  14.4  0.5  0.4  0.9  0.152  -2.1   0.9  -1.2   0.1
# 26   1.5   3.0  ...   10.9  11.7  1.2  0.4  1.6  0.103   0.6  -1.5  -0.8   0.2
# 27   0.2   1.0  ...   15.6  14.8 -0.1  0.0 -0.1 -0.056  -6.7  -1.1  -7.8  -0.1
# 28   2.6   5.6  ...    9.8  21.8  0.9  0.8  1.7  0.124  -0.2  -1.6  -1.7   0.0
# 29   2.9   6.9  ...   11.1  21.3  1.8  0.6  2.4  0.101   1.1  -2.3  -1.2   0.2
# ..   ...   ...  ...    ...   ...  ...  ...  ...    ...   ...   ...   ...   ...
# 448  6.4  14.2  ...   18.7  25.4  3.1  3.3  6.4  0.136   2.4   1.0   3.4   3.1
# 449  0.3   0.9  ...   32.2   8.0 -0.3  0.3  0.0  0.005  -6.1   2.6  -3.5  -0.1
# 450  2.1   4.2  ...   10.3  19.2  0.3  0.1  0.4  0.072  -1.3  -2.7  -4.0  -0.1
# 451  3.1   7.3  ...   18.1  18.2  1.4  1.4  2.8  0.120   0.7   0.1   0.8   0.8
# 452  1.6   4.0  ...   14.6  18.2 -0.4  0.1 -0.3 -0.026  -4.5  -1.9  -6.4  -0.6
# 453  0.7   2.6  ...   17.1  17.5 -0.3  0.2 -0.1 -0.026  -5.3  -1.3  -6.5  -0.2
# 454  5.4  11.1  ...   14.1  21.7  1.1  2.3  3.3  0.114  -0.4   2.6   2.2   1.5
# 455  9.3  21.4  ...   13.6  38.5  5.5  2.5  8.0  0.240   9.4   2.6  12.0   5.6
# 456  4.7   7.5  ...   11.6  21.3  2.1  1.6  3.7  0.231  -1.5   0.3  -1.2   0.1
# 457  1.0   2.1  ...    8.8  23.9  0.3  0.2  0.5  0.205   0.5   0.1   0.6   0.1
# 458  5.9  13.6  ...   11.1  21.9  1.1  0.4  1.5  0.032  -0.7  -1.4  -2.1  -0.1
# 459  0.9   1.9  ...   13.9  20.3  0.1  0.0  0.1  0.057  -0.5  -3.6  -4.1   0.0
# 460  4.3  11.4  ...   14.8  22.4  1.3  0.9  2.2  0.071   0.8  -1.2  -0.4   0.6
# 461  2.5   5.6  ...    9.2  18.1  1.1  0.3  1.4  0.068  -1.0  -2.6  -3.6  -0.4
# 462  1.4   3.3  ...   13.0  18.8  0.1  0.0  0.1  0.070  -0.3  -3.6  -3.9   0.0
# 463  4.5  11.2  ...    8.3  26.7  4.3  0.9  5.2  0.161   4.1  -2.9   1.2   1.3
# 464  2.5   5.8  ...   11.8  13.1  1.0  2.1  3.0  0.103  -0.7   1.9   1.1   1.1
# 465  4.9  12.0  ...   16.2  23.6  2.0  0.3  2.4  0.075   2.7  -3.8  -1.2   0.3
# 466  0.6   2.1  ...    5.9  22.6 -0.1  0.0  0.0 -0.062  -4.7  -3.5  -8.2  -0.1
# 467  2.2   5.2  ...    8.0  14.6  1.3  0.7  1.9  0.096   0.5  -0.9  -0.4   0.4
# 468  0.8   1.7  ...    9.0  18.2  0.4  0.2  0.6  0.140  -2.1  -0.9  -3.0   0.0
# 469  1.0   2.7  ...   17.9  13.3 -0.4  0.2 -0.2 -0.037  -5.9   0.1  -5.8  -0.2
# 470  2.9   4.4  ...    6.5  13.8  3.6  1.3  4.9  0.226   2.1   2.2   4.2   1.6
# 471  1.3   3.4  ...   10.3  17.2  0.5  0.6  1.1  0.139   0.1   1.0   1.1   0.3
# 472  5.8  14.5  ...   18.0  30.7 -0.6  0.8  0.2  0.012   0.4  -1.8  -1.4   0.1
# 473  1.1   3.3  ...    3.9  15.3  0.1  0.2  0.2  0.040  -1.9  -2.2  -4.1  -0.2
# 474  4.1  11.3  ...    7.5  26.0  1.1  0.1  1.2  0.059   1.0  -4.2  -3.2  -0.3
# 475  5.9  12.8  ...    9.7  21.3  1.4  1.1  2.4  0.064   0.4  -0.1   0.3   1.1
# 476  2.8   6.1  ...   12.3  15.6  1.7  2.2  3.9  0.129  -1.9   2.5   0.7   1.0
# 477  3.9   7.1  ...   10.5  19.1  3.2  1.3  4.5  0.167   0.2   0.4   0.7   0.9
#
# [478 rows x 49 columns]

# %% [markdown]
# #### #8. Plot the number of guards, centers, and forwards in this data set.

# %%
pd.plotting.scatter_matrix(nba_df[['pos','pts','age','fg']],figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121f0c278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12203c080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122064518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12208ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1220bd048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1220e25c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12210ab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12213a128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12213a160>]],
#       dtype=object)

# %%
nba_df['pos'].value_counts().plot(kind='bar')

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
